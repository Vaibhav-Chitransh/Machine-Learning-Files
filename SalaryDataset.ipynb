# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv('Salary_Data.csv')

# %%
dataset
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088

# %%
x = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %%
from sklearn.model_selection import train_test_split   #Splitting the dataset into the training set and test set
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state = True)
print(x_train)
# Out:
# [[3.2]
#  [4.9]
#  [2.2]
#  [1.3]
#  [3.9]
#  [1.1]
#  [5.3]
#  [5.1]
#  [3.7]
#  [3.2]
#  [4. ]
#  [4. ]
#  [2.9]]

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
print('Test data set y value', y_test)
y_pred = regressor.predict(x_test)
print('Predicted', y_pred)
# Out:
# Test data set y value [60150 43525 57081 37731 61111]
# Predicted [54292.5905603  46468.39698856 62899.20348921 42556.30020269
#  66028.88091791]

# %%
coef = regressor.coef_
interc = regressor.intercept_
print('Coefficient', coef)
print('Intercept', interc)
# Out:
# Coefficient [7824.19357174]
# Intercept 30820.009845084696

# %%
from sklearn.metrics import r2_score
R_square = r2_score(y_test, y_pred)
print('Coefficient of Determination', R_square)
# Out:
# Coefficient of Determination 0.7241890331700446

# %%
dataset.corr
# Out:
# <bound method DataFrame.corr of     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088>

# %%
plt.scatter(x_train, y_train, color = 'grey')
plt.plot(x_train, regressor.predict(x_train), color = 'aqua')
plt.title('Salary vs Experience (Training set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %%
plt.scatter(x_test, y_test, color='aqua')
plt.plot(x_test, regressor.predict(x_test), color = 'black')
plt.title('Salary vs Experience (Test set)')
plt.xlabel('Years of Experience')
plt.ylabel('salary')
plt.show()

# %%
dataset2 = pd.read_csv('score_updated.csv')

# %%
dataset2
# Out:
#     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# ..    ...     ...
# 91    5.8      60
# 92    4.4      44
# 93    6.1      63
# 94    3.7      37
# 95    8.0      84
#
# [96 rows x 2 columns]

# %%
X = dataset2.iloc[ : , :-1]
Y = dataset2.iloc[ : , :-1]

# %%
from sklearn.model_selection import train_test_split   #Splitting the dataset into the training set and test set
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.25, random_state = True)

# %%
from sklearn.linear_model import LinearRegression
regressor2 = LinearRegression()
regressor2.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
print('Test data set y value', Y_test)
Y_pred = regressor2.predict(X_test)
print('Predicted', Y_pred)
# Out:
# Test data set y value     Hours
# 40    1.8
# 31    9.0
# 46    8.0
# 59    6.4
# 78    5.6
# 74    2.9
# 65    8.2
# 44    7.3
# 80    2.6
# 85    5.0
# 62    3.4
# 27    5.8
# 91    5.8
# 77    4.9
# 32    6.2
# 56    8.4
# 39    4.4
# 10    7.7
# 2     3.2
# 38    5.3
# 54    2.4
# 58    5.2
# 19    7.4
# 90    9.8
# Predicted [[1.8]
#  [9. ]
#  [8. ]
#  [6.4]
#  [5.6]
#  [2.9]
#  [8.2]
#  [7.3]
#  [2.6]
#  [5. ]
#  [3.4]
#  [5.8]
#  [5.8]
#  [4.9]
#  [6.2]
#  [8.4]
#  [4.4]
#  [7.7]
#  [3.2]
#  [5.3]
#  [2.4]
#  [5.2]
#  [7.4]
#  [9.8]]

# %%
coefficient = regressor2.coef_
intercept = regressor2.intercept_
print('Coefficient', coefficient)
print('Intercept', intercept)
# Out:
# Coefficient [[1.]]
# Intercept [8.8817842e-16]
